# %% [markdown]
# <a href="https://colab.research.google.com/github/saneeshaparna39-dotcom/ML-assignment/blob/main/churn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
df=pd.read_csv('/content/Churn.csv')
print(df)
print(df.columns)
df.head()
x=pd.get_dummies(df.drop(['Churn','Customer ID'],axis=1))
y=df['Churn'].apply(lambda x:1 if x=='Yes' else 0)
print(x,y)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_12767/1064710865.py in <cell line: 0>()
#       1 import pandas as pd
#       2 from sklearn.model_selection import train_test_split
# ----> 3 df=pd.read_csv('/content/Churn.csv')
#       4 print(df)
#       5 print(df.columns)
#
# ...

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
df=pd.read_csv('/content/Churn.csv')
print(df)
print(df.columns)
df.head()
x=pd.get_dummies(df.drop(['Churn','Customer ID'],axis=1))
y=df['Churn'].apply(lambda x:1 if x=='Yes' else 0)
print(x,y)

# %%
x=pd.get_dummies(df.drop(['Churn','Customer ID'],axis=1))
y=df['Churn'].apply(lambda x:1 if x=='Yes' else 0)
print(x,y)
# Out:
#       Senior Citizen  tenure  ...  Total Charges_999.8  Total Charges_999.9
# 0                  0       1  ...                False                False
# 1                  0       1  ...                False                False
# 2                  0      34  ...                False                False
# 3                  0       2  ...                False                False
# 4                  0      45  ...                False                False
# ...              ...     ...  ...                  ...                  ...
# 7039               0      24  ...                False                False
# 7040               0      72  ...                False                False
# 7041               0      11  ...                False                False
# 7042               1       4  ...                False                False
# 7043               0      66  ...                False                False
#
# [7044 rows x 6575 columns] 0       0
# 1       0
# ...

# %%
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense
from sklearn.metrics import accuracy_score
