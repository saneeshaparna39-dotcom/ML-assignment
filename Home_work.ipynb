# %% [markdown]
# <a href="https://colab.research.google.com/github/saneeshaparna39-dotcom/ML-assignment/blob/main/Home_work.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def square(n):
    return n**2
print(square(3))
# Out:
# 9

# %%
def is_prime(n):
  if n<=1:
    return False
  if n<=3:
    return True
print(is_prime(2))
# Out:
# True
